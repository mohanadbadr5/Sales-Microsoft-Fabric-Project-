# %% [markdown]
# # **Sales Analytics Data Notebook**

# %%
table_name = "sales"
# Out:
# StatementMeta(, 51ab8f55-7a8a-465e-842e-31e20886870e, 3, Finished, Available, Finished, False)

# %%
from pyspark.sql.functions import *
# Out:
# StatementMeta(, 51ab8f55-7a8a-465e-842e-31e20886870e, 5, Finished, Available, Finished, False)

# %%
df = spark.read.format("csv").option("header",True).load("Files/Data_Source")
# adding month and year column
df = df.withColumn("Year", year(col("OrderDate"))).withColumn("Month", month(col("OrderDate")))
# loading the data into table
df.write.format("delta").mode("append").saveAsTable(table_name)
display(df)
# Out:
# StatementMeta(, 51ab8f55-7a8a-465e-842e-31e20886870e, 15, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 7fbd55ba-0371-4979-848b-1c45ec19459c)
